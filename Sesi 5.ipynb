# %% [markdown]
# ## Pandas Introduction

# %% [markdown]
# ## Using the Pandas Python Library

# %%
import numpy as np
import pandas as pd

# %%
#membaca file csv dan memasukkannya ke dataframe
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
#melihat banyak baris data nba
len(df)
# Out:
# 126314

# %%
df.shape #melihat banyak baris dan dimensi data nba
# Out:
# (126314, 23)

# %% [markdown]
# terdapat 126314 baris dan 23 kolom

# %%
#melihat 5 baris pertama
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
#menampilkan semua kolom (menampilkan kolom yang ...)
pd.set_option("display.max.columns", None)

# %%
#mengubah dari 6 desimal menjadi 2 desimal
pd.set_option("display.precision", 2)

# %%
#.tail() untuk menampilkan 5 baris terakhir
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
#menampilkan tiga baris terakhir
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %% [markdown]
# ## Getting to Know Your Data
# ### Displaying Data Types

# %%
#menampilkan semua kolom dan tipe datanya
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ### Showing Basic Statistics

# %%
#mendapatkan overview tentang nilai yang terkandung di setiap kolom
df.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %% [markdown]
# ### Exploring Your Dataset

# %%
#memeriksa seberapa sering nilai tertentu muncul dalam kolom
df["team_id"].value_counts()
# Out:
# team_id
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: count, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# fran_id
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df['fran_id'] == 'Lakers', "team_id"].value_counts()
# Out:
# team_id
# LAL    5078
# MNL     946
# Name: count, dtype: int64

# %%
#mengetahui tanggal pertama bermain
df.loc[df['team_id'] == 'MNL', "date_game"].min()
# Out:
# '1/1/1949'

# %%
#mengetahui tanggal terakhir bermain
df.loc[df['team_id'] == 'MNL', "date_game"].max()
# Out:
# '4/9/1959'

# %%
# get min and max with aggregation
df.loc[df['team_id'] == 'MNL', "date_game"].agg(('min','max'))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
#mengetahui berapa point yang dicetak
df[df.team_id == 'BOS'].pts.sum()
# Out:
# 626484

# %% [markdown]
# ## Getting to Know Pandas Data Structure
# ### Understanding Series Object

# %%
#buat object series baru
revenues = pd.Series([555,7000,9999])
revenues
# Out:
# 0     555
# 1    7000
# 2    9999
# dtype: int64

# %% [markdown]
# revenues.values mengembalikan nilai dalam seri, sedangkan revenues.index mengembalikan indeks posisi

# %%
revenues.values
# Out:
# array([ 555, 7000, 9999], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
city_revenues = pd.Series([555,7000,9999], index=['Padang', 'Batam','Kediri'])
city_revenues
# Out:
# Padang     555
# Batam     7000
# Kediri    9999
# dtype: int64

# %%
city_employee_counts = pd.Series({'Padang':10, 'Batam':56})
city_employee_counts
# Out:
# Padang    10
# Batam     56
# dtype: int64

# %%
city_employee_counts.keys()
# Out:
# Index(['Padang', 'Batam'], dtype='object')

# %%
city_revenues.keys()
# Out:
# Index(['Padang', 'Batam', 'Kediri'], dtype='object')

# %%
'Padang' in city_revenues
# Out:
# True

# %% [markdown]
# ### Understanding DataFrame Objects

# %%
# making a dataframe
city_data = pd.DataFrame({
    'revenue':city_revenues,
    'employee_count':city_employee_counts
})

city_data
# Out:
#         revenue  employee_count
# Batam      7000            56.0
# Kediri     9999             NaN
# Padang      555            10.0

# %%
city_data.index
# Out:
# Index(['Batam', 'Kediri', 'Padang'], dtype='object')

# %%
city_data.values
# Out:
# array([[7000.,   56.],
#        [9999.,   nan],
#        [ 555.,   10.]])

# %%
#merujuk ke 2 dimensi dataframe sebagai axes
city_data.axes
# Out:
# [Index(['Batam', 'Kediri', 'Padang'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Batam', 'Kediri', 'Padang'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %% [markdown]
# Axis 0 adalah indeks baris, axis 1 adalah indeks kolom

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
'points' in df.keys()
# Out:
# False

# %%
'pts' in df.keys()
# Out:
# True

# %% [markdown]
# ### Accesing Series Elements
# #### Using the indexing operator

# %% [markdown]
# Series memiliki dua indeks:
# - Indeks posisi atau implisit, yang selalu berupa RangeIndex
# - Label atau indeks eksplisit, yang dapat berisi objek yang dapat di-hash

# %%
city_revenues
# Out:
# Padang     555
# Batam     7000
# Kediri    9999
# dtype: int64

# %%
#mengakses nilai dalam series dengan indeks label dan posisi
city_revenues["Padang"]
# Out:
# 555

# %%
city_revenues[1]
# Out:
# 7000

# %%
#menggunakan indeks slicing negatif
city_revenues[-1]
# Out:
# 9999

# %%
city_revenues[1:]
# Out:
# Batam     7000
# Kediri    9999
# dtype: int64

# %% [markdown]
# #### Using .loc dan .iloc

# %%
colors = pd.Series(
    ['red', 'purple','blue','green','yellow'],
    index = [1,2,3,5,8]
)
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.loc[3]
# Out:
# 'blue'

# %%
colors.iloc[3]
# Out:
# 'green'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %% [markdown]
# ### Accesing DataFrame Elements

# %% [markdown]
# #### Using the indexing operators

# %%
city_data["revenue"]
# Out:
# Batam     7000
# Kediri    9999
# Padang     555
# Name: revenue, dtype: int64

# %%
city_data.revenue
# Out:
# Batam     7000
# Kediri    9999
# Padang     555
# Name: revenue, dtype: int64

# %%
toys = pd.DataFrame([{"name toys": "ball", "shape": "circular"}, {"name toys": "rubik's cube", "shape": "cube"}])
toys
# Out:
#       name toys     shape
# 0          ball  circular
# 1  rubik's cube      cube

# %%
toys["shape"]
# Out:
# 0    circular
# 1        cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %% [markdown]
# #### Using .loc and .iloc

# %%
city_data
# Out:
#         revenue  employee_count
# Batam      7000            56.0
# Kediri     9999             NaN
# Padang      555            10.0

# %%
city_data.loc["Batam"]
# Out:
# revenue           7000.0
# employee_count      56.0
# Name: Batam, dtype: float64

# %% [markdown]
# ## Querying Your Dataset
# memilih baris berdasarkan nilai di kolom kumpulan data untuk query data

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i                 1700.74
# elo_n                 1692.09
# win_equiv               59.29
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i             1813.63
# opp_elo_n             1822.29
# game_location               H
# game_result                 L
# forecast                 0.48
# notes                     NaN
# Name: 126312, dtype: object

# %%
df.iloc[-3,0:6]
# Out:
# gameorder           63156
# game_id      201506140GSW
# lg_id                 NBA
# _iscopy                 1
# year_id              2015
# date_game       6/14/2015
# Name: 126311, dtype: object

# %%
df.loc[126310:126312,'game_id':'year_id']
# Out:
#              game_id lg_id  _iscopy  year_id
# 126310  201506140GSW   NBA        0     2015
# 126311  201506140GSW   NBA        1     2015
# 126312  201506170CLE   NBA        0     2015

# %%
current_decade = df[df['year_id'] > 2011]
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 116278      58140  201112250DAL   NBA        1     2012  12/25/2011
# 116279      58140  201112250DAL   NBA        0     2012  12/25/2011
# 116280      58141  201112250GSW   NBA        1     2012  12/25/2011
# 116281      58141  201112250GSW   NBA        0     2012  12/25/2011
# 116282      58142  201112250LAL   NBA        0     2012  12/25/2011
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 116278           1            0     MIA       Heat  105  1652.40  1668.89
# ...

# %%
current_decade.shape
# Out:
# (10036, 23)

# %%
#memilih baris dimana field tertentu yang bukan null
df[df.notes.notnull()]
df[df.notes.notna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
df.fran_id.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: fran_id
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  object
# dtypes: object(1)
# memory usage: 987.0+ KB

# %%
#mengakses nilai dari tipe data objek sebagai str dan melakukan metode string
df[df.fran_id.str.endswith('ers')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
df[
    (df["_iscopy"] == 0) & #untuk menyertakan entry yang bukan duplikat
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %% [markdown]
# ## Grouping and Aggregating Your Data

# %%
city_revenues.sum()
# Out:
# 17554

# %%
city_revenues.min()
# Out:
# 555

# %%
poin = df['pts']
poin.sum()
# Out:
# 12976235

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.0  1309.65      42.01    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68    1300.00    1306.72             H           L      0.64
# 1  Huskies       66    1300.00    1293.28             A           W      0.36
# 2   Knicks       47    1306.72    1297.07             H           W      0.63
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
# mengelompokan df dengan beberapa kolom dan urutannya beraturan
df.groupby('fran_id', sort = False)['pts'].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
#mengelompokkan beberapa kolom
df[
    (df["fran_id"] == "Heat") &
    (df["year_id"] > 2013)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2014     L              35
#          W              67
# 2015     L              45
#          W              37
# Name: game_id, dtype: int64

# %% [markdown]
# ## Manipulating Columns

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
#membuat salinan df
nba = df.copy()
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# membuat sebuah kolom baru
nba['difference'] = df.pts - df.opp_pts
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
#menemukan nilai terbesar dari kolom baru
nba['difference'].max()
# Out:
# 68

# %%
#mengganti kolom "game_result" dengan "result" dan "game_location" dengan "location"
renamed_nba = nba.rename(columns= {"game_result":"result", "game_location":"location"})
renamed_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# inplace for updating a dataframe
nba.rename(columns= {"game_result":"result", "game_location":"location"}, inplace = True)
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'location', 'result', 'forecast', 'notes', 'difference'],
#       dtype='object')

# %%
elo_columns = ['elo_i','elo_n','opp_elo_i','opp_elo_n',]

# %%
nba.drop(columns = elo_columns, inplace = True)
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba.shape
# Out:
# (126314, 20)

# %% [markdown]
# ## Specifying Data Types

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  object
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  object
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
nba['date_game'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: date_game
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  object
# dtypes: object(1)
# memory usage: 987.0+ KB

# %%
#mengubah semua tanggal game sebagai objek datatime
nba['date_game']= pd.to_datetime(nba['date_game'])

# %%
nba['date_game'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: date_game
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 987.0 KB

# %%
# total unique values
nba.location.nunique()
# Out:
# 3

# %%
# display every unique values
nba.location.unique()
# Out:
# array(['H', 'A', 'N'], dtype=object)

# %%
nba.location.value_counts()
# Out:
# location
# H    63138
# A    63138
# N       38
# Name: count, dtype: int64

# %%
nba.location.dtype
# Out:
# dtype('O')

# %%
# changing type into categorical
nba.location = pd.Categorical(nba.location)

# %%
nba.location.dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %% [markdown]
# ## Missing Values

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  category
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
#menghapus semua baris dengan nilai yang hilang menggunakan .dropna()
row_missing = nba.dropna()
row_missing
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 930           466  194801300BLB   NBA        1     1948 1948-01-30
# 931           466  194801300BLB   NBA        0     1948 1948-01-30
# 1084          543  194803230CHS   NBA        1     1948 1948-03-23
# 1085          543  194803230CHS   NBA        0     1948 1948-03-23
# 1088          545  194803250CHS   NBA        1     1948 1948-03-25
# ...           ...           ...   ...      ...      ...        ...
# 122207      61104  201401160ATL   NBA        0     2014 2014-01-16
# 123916      61959  201411120MIN   NBA        1     2015 2014-11-12
# 123917      61959  201411120MIN   NBA        0     2015 2014-11-12
# 124862      62432  201501150MIL   NBA        0     2015 2015-01-15
# 124863      62432  201501150MIL   NBA        1     2015 2015-01-15
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 930             28            0     WSC      Capitols   71      47.07    BLB
# ...

# %%
row_missing.shape
# Out:
# (5424, 20)

# %%
row_missing = nba.dropna(axis=1)
row_missing
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
row_missing.shape
# Out:
# (126314, 19)

# %%
# fill null values
data_with_default_notes = nba.copy()
data_with_default_notes['notes'].fillna(
    value = "no notes at all",
    inplace = True
)
data_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
data_with_default_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  category
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %% [markdown]
# ## Invalid Values

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id                      date_game  \
# count  126314.00  126314.0  126314.00                         126314
# mean    31579.00       0.5    1988.20  1988-04-09 00:53:18.429311104
# min         1.00       0.0    1947.00            1946-11-01 00:00:00
# 25%     15790.00       0.0    1975.00            1974-11-08 00:00:00
# 50%     31579.00       0.5    1990.00            1990-02-06 00:00:00
# 75%     47368.00       1.0    2003.00            2003-03-19 00:00:00
# max     63157.00       1.0    2015.00            2015-06-16 00:00:00
# std     18231.93       0.5      17.58                            NaN
#
#        seasongame  is_playoffs        pts  win_equiv    opp_pts   forecast  \
# count   126314.00    126314.00  126314.00  126314.00  126314.00  126314.00
# mean        43.53         0.06     102.73      41.71     102.73       0.50
# min          1.00         0.00       0.00      10.15       0.00       0.02
# ...

# %%
nba[nba.pts == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       location result  forecast                           notes  difference
# 26684        A      L      0.33  at Richmond VA; forfeit to VIR          -2

# %% [markdown]
# #### Inconsistent values

# %%
#nilai kolom pts, opp_pts, dan game_result harus konsistent satu sama lain
nba[(nba["pts"] > nba["opp_pts"]) & (nba["result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["result"] != 'W')].empty
# Out:
# False

# %% [markdown]
# ## Combining Multiple Datasets

# %%
#menggabungkan city_data dengan df lain
further_city_data = pd.DataFrame(
{"revenue": [7000, 3400], "employee_count": [2, 2]}, index=["New York", "Barcelona"])
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#         revenue  employee_count
# Batam      7000            56.0
# Kediri     9999             NaN
# Padang      555            10.0

# %%
all_city = pd.concat([further_city_data, city_data])
all_city
# Out:
#            revenue  employee_count
# New York      7000             2.0
# Barcelona     3400             2.0
# Batam         7000            56.0
# Kediri        9999             NaN
# Padang         555            10.0

# %%
city_countries = pd.DataFrame({ "country": ["Holland", "Japan", "Holland", "Canada", "Spain"], "capital": [1, 1, 0, 0, 0]},
index=["Bandung", "Jakarta", "Pekanbaru", "Toronto", "Barcelona"])
city_countries
# Out:
#            country  capital
# Bandung    Holland        1
# Jakarta      Japan        1
# Pekanbaru  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities = pd.concat([all_city, city_countries], axis = 1)
cities
# Out:
#            revenue  employee_count  country  capital
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Batam       7000.0            56.0      NaN      NaN
# Kediri      9999.0             NaN      NaN      NaN
# Padang       555.0            10.0      NaN      NaN
# Bandung        NaN             NaN  Holland      1.0
# Jakarta        NaN             NaN    Japan      1.0
# Pekanbaru      NaN             NaN  Holland      0.0
# Toronto        NaN             NaN   Canada      0.0

# %%
#menggabungkan kota hanya yang muncul di kedua objek df, maka diatur paratemeternya join menjadi inner join
pd.concat([all_city, city_countries], axis = 1, join = 'inner')
# Out:
#            revenue  employee_count country  capital
# Barcelona     3400             2.0   Spain        0

# %%
countries = pd.DataFrame({ "population_millions": [17, 127, 37],
"continent":["Europe", "Asia", "North America"]
}, index=["Bandung", "Jakarta", "Canada"])
countries
# Out:
#          population_millions      continent
# Bandung                   17         Europe
# Jakarta                  127           Asia
# Canada                    37  North America

# %% [raw]
# cities

# %%
# joining 2 or more dataframes
pd.merge(cities, countries, left_on='country', right_index = True, how='outer')
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# New York    7000.0             2.0      NaN      NaN                  NaN
# Batam       7000.0            56.0      NaN      NaN                  NaN
# Kediri      9999.0             NaN      NaN      NaN                  NaN
# Padang       555.0            10.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Bandung        NaN             NaN  Holland      1.0                  NaN
# Pekanbaru      NaN             NaN  Holland      0.0                  NaN
# Jakarta        NaN             NaN    Japan      1.0                  NaN
# Toronto        NaN             NaN   Canada      0.0                 37.0
# NaN            NaN             NaN  Bandung      NaN                 17.0
# NaN            NaN             NaN  Jakarta      NaN                127.0
#
#                continent
# New York             NaN
# Batam                NaN
# ...

# %% [markdown]
# ## Visualizing Your Pandas DataFrame

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
#visualisasi berapa banyak poin yang dicetak Knicks sepanjang musim
nba[nba.fran_id == 'Knicks'].groupby('year_id')['pts'].sum().plot()
# Out:
# <Axes: xlabel='year_id'>

# %%
nba[nba.fran_id == 'Knicks'].groupby('year_id')['pts'].sum()
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
nba.fran_id.value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='fran_id'>

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# fran_id
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: count, dtype: int64
